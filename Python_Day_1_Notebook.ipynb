# %% [markdown]
# <a href="https://colab.research.google.com/github/yusufsjustit/13-Python-Projects/blob/main/Day_1_Python_Notebook_Regional_06_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# run code

# %% [markdown]
# Text cells are used to create section in your notebook.

# %% [markdown]
# # This is the title of the section

# %% [markdown]
# ## This is a sub-section

# %% [markdown]
# # This is another section

# %% [markdown]
# # Print Function

# %%
# !python --version
# Out:
# Python 3.12.12

# %% [markdown]
# String object must be enclodes by "" or '' in Python.

# %%
print("Yusuf")
# Out:
# Yusuf

# %%
print('I love football.')
# Out:
# I love football.

# %%
print(3.14)
# Out:
# 3.14

# %%
print('I need to study")
# Out:
#   File "/tmp/ipython-input-1702149760.py", line 1
#     print('I need to study")
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('My father's favorite car is Toyota')
# Out:
#   File "/tmp/ipython-input-2771373131.py", line 1
#     print('My father's favorite car is Toyota')
#                                              ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("My father's favorite car is Toyota")
# Out:
# My father's favorite car is Toyota

# %% [markdown]
# ## Escape Characters

# %%
print('My father\'s favourite car is Toyota')
# Out:
# My father's favorite car is Toyota

# %%
print("The itsy bitsy spider\nclimbed up the waterspout.")

print()

print("Down came the rain\nand washed the spider out.")
# Out:
# The itsy bitsy spider
# climbed up the waterspout.
#
# Down came the rain
# and washed the spider out.

# %%
print("I am learning Python")
# Out:
# I am learning Python

# %%
print(len("I am learning Python"))
# Out:
# 20

# %%
print("print \\")
# Out:
# print \

# %%
print(3.14)
# Out:
# 3.14

# %%
print("2" + "3")

print(2 + 3)
# Out:
# 23
# 5

# %% [markdown]
# When used between string objects, + will behave like concatenation operator

# %% [markdown]
# When used between numeric objects, + will behave like arithmetic operator

# %%
print("2", "3")
# Out:
# 2 3

# %%
print("2", 3, True, 3.14)
# this is an example of multiple arguments in Python
# Out:
# 2 3 True 3.14

# %%
print("2", 3, True, 3.14) # this is an example of multiple arguments in Python
# Out:
# 2 3 True 3.14

# %%
# this is an example of multiple arguments in Python

print("Yusuf", 31)

# here is another example

print(3+5)
# Out:
# Yusuf 31
# 8

# %% [markdown]
# # Variable

# %%
my_name = "Yusuf"
# This code will assign value Yusuf to variable my_name

# %%
print(my_name)
# Out:
# Yusuf

# %%
print(myname)
# myname is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3989149940.py in <cell line: 0>()
# ----> 1 print(myname)
#       2 # myname is not defined
#
# NameError: name 'myname' is not defined

# %%
my_age = 18
print(my_age)
# Out:
# 18

# %%
my_age = 33
your_age = 30
my_age = your_age # in this step value of your_age will be assigned to my_age
print(my_age)
print(my_age, your_age)
# Out:
# 30
# 30 30

# %% [markdown]
# ## Naming Rules
#
#
# 1.   dont start with numbers
# 2.   dont use space in variable name
# 3. Dont start with uppercase
# 4. you can only use _

# %% [markdown]
# # input() function

# %%
input("Write something:")
# Out:
# Write something:25
# '25'

# %%
print(2)
# Out:
# 2

# %%
print("Tell me a joke.")
anything = input()
print("Hmm.. ", anything, "interesting")
# Out:
# Tell me a joke.
# you tell me
# Hmm..  you tell me interesting

# %%
# simple calculator
print("This is a simple calculator.")
number1 = input("Enter the first number: ")
number2 = input("Enter the second number: ")

print(number1, "added to", number2, "is", number1+number2)

print(type(number1))
print(type(number2))
# Out:
# This is a simple calculator.
# Enter the first number: 3.10
# Enter the second number: 2.20
# 3.10 added to 2.20 is 3.102.20
# <class 'str'>
# <class 'str'>

# %% [markdown]
# ### There are 3 function for type conversion
#
#
# 1.   int(): convert to integer data type
# 2.   str(): convert to string data type
# 3. float(): convert to decimal

# %%
# simple calculator
print("This is a simple calculator.")
# convert results of input function to integers
number1 = int(input("Enter the first number: ")) # input converted to int
number2 = int(input("Enter the second number: ")) # input converted to int

print(number1, "added to", number2, "is", number1+number2)
# Out:
# This is a simple calculator.
# Enter the first number: 20
# Enter the second number: 25
# 20 added to 25 is 45

# %%
# simple calculator
print("This is a simple calculator.")
# convert results of input function to integers
number1 = float(input("Enter the first number: ")) # input converted to float
number2 = float(input("Enter the second number: ")) # input converted to float
# float type conversion is safer. Because int function cant convert float to integer

print(number1, "added to", number2, "is", number1+number2)
# Out:
# This is a simple calculator.
# Enter the first number: 2.0
# Enter the second number: 3.4
# 2.0 added to 3.4 is 5.4

# %%
# simple calculator
print("This is a simple calculator.")
# convert results of input function to integers
number1 = float(input("Enter the first number: ")) # input converted to float
number2 = float(input("Enter the second number: ")) # input converted to float
# float type conversion is safer. Because int function cant convert float to integer

print(number1, "added to", number2, "is", number1+number2)

print(number1, "divided by", number2, "is", number1/number2)

print(number1, "multiply by", number2, "is", number1*number2)

print(number1, "raised to power", number2, "is", number1**number2)

print(number1, "square root", "is", number1**0.5)
# Out:
# This is a simple calculator.
# Enter the first number: 16
# Enter the second number: 2
# 16.0 added to 2.0 is 18.0
# 16.0 divided by 2.0 is 8.0
# 16.0 multiply by 2.0 is 32.0
# 16.0 raised to power 2.0 is 256.0
# 16.0 square root is 4.0
